# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# ## Video segmentation and tracking with SAM 3
#
# This notebook demonstrates how to use SAM 3 for interactive video segmentation and dense tracking. It covers the following capabilities:
#
# - **Text prompts**: Using natural language descriptions to segment objects (e.g., "person", "shoe")
# - **Point prompts**: Adding positive/negative clicks to segment and refine objects
#
# We use the terms _segment_ or _mask_ to refer to the model prediction for an object on a single frame, and _masklet_ to refer to the spatio-temporal masks across the entire video.

# %% [markdown]
# # <a target="_blank" href="https://colab.research.google.com/github/facebookresearch/sam3/blob/main/notebooks/sam3_video_predictor_example.ipynb">
# #   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# # </a>

# %%
using_colab = True

# %%
if using_colab:
    import torch
    import torchvision
    print("PyTorch version:", torch.__version__)
    print("Torchvision version:", torchvision.__version__)
    print("CUDA is available:", torch.cuda.is_available())
    import sys
    # !{sys.executable} -m pip install opencv-python matplotlib scikit-learn
    # !git config --global http.postBuffer 524288000
    # !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/sam3.git'
# Out:
# PyTorch version: 2.5.1+cu121
# Torchvision version: 0.20.1+cu121
# CUDA is available: True
# Requirement already satisfied: opencv-python in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (3.10.9)
# Requirement already satisfied: scikit-learn in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.21.2 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting git+https://github.com/facebookresearch/sam3.git
#   Cloning https://github.com/facebookresearch/sam3.git to /tmp/pip-req-build-h1egniqa
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/sam3.git /tmp/pip-req-build-h1egniqa
#   Resolved https://github.com/facebookresearch/sam3.git to commit 875ed6fa5af25f80e424a2e737940a65e13e8cbf
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: timm>=1.0.17 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from sam3==0.1.0) (1.0.26)
# Requirement already satisfied: numpy<2,>=1.26 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from sam3==0.1.0) (1.26.4)
# Requirement already satisfied: tqdm in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from sam3==0.1.0) (4.67.3)
# Requirement already satisfied: ftfy==6.1.1 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from sam3==0.1.0) (6.1.1)
# Requirement already satisfied: regex in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from sam3==0.1.0) (2026.4.4)
# Requirement already satisfied: iopath>=0.1.10 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from sam3==0.1.0) (0.1.10)
# Requirement already satisfied: typing_extensions in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from sam3==0.1.0) (4.15.0)
# Requirement already satisfied: huggingface_hub in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from sam3==0.1.0) (1.12.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from ftfy==6.1.1->sam3==0.1.0) (0.6.0)
# Requirement already satisfied: portalocker in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from iopath>=0.1.10->sam3==0.1.0) (3.2.0)
# Requirement already satisfied: torch in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from timm>=1.0.17->sam3==0.1.0) (2.5.1+cu121)
# Requirement already satisfied: torchvision in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from timm>=1.0.17->sam3==0.1.0) (0.20.1+cu121)
# Requirement already satisfied: pyyaml in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from timm>=1.0.17->sam3==0.1.0) (6.0.3)
# Requirement already satisfied: safetensors in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from timm>=1.0.17->sam3==0.1.0) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (26.0)
# Requirement already satisfied: typer in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from huggingface_hub->sam3==0.1.0) (0.25.0)
# Requirement already satisfied: anyio in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (4.13.0)
# Requirement already satisfied: certifi in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (1.0.9)
# Requirement already satisfied: idna in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (3.13)
# Requirement already satisfied: h11>=0.16 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->sam3==0.1.0) (0.16.0)
# Requirement already satisfied: networkx in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (3.1.0)
# Requirement already satisfied: setuptools in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (82.0.1)
# Requirement already satisfied: sympy==1.13.1 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torch->timm>=1.0.17->sam3==0.1.0) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->timm>=1.0.17->sam3==0.1.0) (12.8.93)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from sympy==1.13.1->torch->timm>=1.0.17->sam3==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from jinja2->torch->timm>=1.0.17->sam3==0.1.0) (3.0.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from torchvision->timm>=1.0.17->sam3==0.1.0) (12.1.1)
# Requirement already satisfied: click>=8.2.1 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from typer->huggingface_hub->sam3==0.1.0) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from typer->huggingface_hub->sam3==0.1.0) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from typer->huggingface_hub->sam3==0.1.0) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from typer->huggingface_hub->sam3==0.1.0) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from rich>=13.8.0->typer->huggingface_hub->sam3==0.1.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from rich>=13.8.0->typer->huggingface_hub->sam3==0.1.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->huggingface_hub->sam3==0.1.0) (0.1.2)

# %%
# !nvidia-smi
# Out:
# Mon Apr 27 17:49:19 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     On  |   00000000:83:00.0 Off |                  N/A |
# | 29%   16C    P8              7W /  250W |       5MiB /  11264MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from huggingface_hub import login
import os
TOKEN = os.getenv("TOKEN")
login(token=TOKEN)

# %% [markdown]
# ## Set-up
#
# In this example, we allow running inference either on a single GPU or multiple GPUs.

# %%
import os

class SmartPkgResources:
    @staticmethod
    def resource_filename(package_name, resource_name):
        import importlib
        # On trouve le vrai chemin où SAM 3 est installé sur ton serveur
        chemin_package = os.path.dirname(importlib.import_module(package_name).__file__)
        vrai_chemin = os.path.join(chemin_package, resource_name)
        print(f"🔧 Fichier trouvé et redirigé : {vrai_chemin}")
        return vrai_chemin

# 2. On injecte ce remplaçant dans le cerveau de Python
sys.modules["pkg_resources"] = SmartPkgResources()

import sam3
import torch

sam3_root = os.path.join(os.path.dirname(sam3.__file__), "..")

# use all available GPUs on the machine
gpus_to_use = range(torch.cuda.device_count())
# # use only a single GPU
# gpus_to_use = [torch.cuda.current_device()]
# Out:
# /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/model_misc.py:70: UserWarning: Flash Attention is disabled as it requires a GPU with Ampere (8.0) CUDA capability.
#   OLD_GPU, USE_FLASH_ATTN, MATH_KERNEL_ON = get_sdpa_settings()
# /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
from sam3.model_builder import build_sam3_video_predictor

predictor = build_sam3_video_predictor(gpus_to_use=gpus_to_use)
# Out:
# INFO 2026-04-27 17:49:20,969 193877 sam3_video_predictor.py: 109: using the following GPU IDs: [0]
# INFO 2026-04-27 17:49:20,971 193877 sam3_video_predictor.py: 125:
#
#
# 	*** START loading model on all ranks ***
#
#
# INFO 2026-04-27 17:49:20,971 193877 sam3_video_predictor.py: 127: loading model on rank=0 with world_size=1 -- this could take a while ...
# 🔧 Fichier trouvé et redirigé : /home/mklinkenberg/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/assets/bpe_simple_vocab_16e6.txt.gz
# INFO 2026-04-27 17:49:32,770 193877 sam3_video_base.py: 348: setting max_num_objects=10000 and num_obj_for_compile=16
# INFO 2026-04-27 17:49:36,644 193877 sam3_video_predictor.py: 129: loading model on rank=0 with world_size=1 -- DONE locally
# INFO 2026-04-27 17:49:36,644 193877 sam3_video_predictor.py: 140:
#
#
# 	*** DONE loading model on all ranks ***

# %% [markdown]
# #### Inference and visualization utils

# %%
import glob
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from sam3.visualization_utils import (
    load_frame,
    prepare_masks_for_visualization,
    visualize_formatted_frame_output,
)

# font size for axes titles
plt.rcParams["axes.titlesize"] = 12
plt.rcParams["figure.titlesize"] = 12


def propagate_in_video(predictor, session_id):
    # we will just propagate from frame 0 to the end of the video
    outputs_per_frame = {}
    for response in predictor.handle_stream_request(
        request=dict(
            type="propagate_in_video",
            session_id=session_id,
        )
    ):
        outputs_per_frame[response["frame_index"]] = response["outputs"]

    return outputs_per_frame


def abs_to_rel_coords(coords, IMG_WIDTH, IMG_HEIGHT, coord_type="point"):
    """Convert absolute coordinates to relative coordinates (0-1 range)

    Args:
        coords: List of coordinates
        coord_type: 'point' for [x, y] or 'box' for [x, y, w, h]
    """
    if coord_type == "point":
        return [[x / IMG_WIDTH, y / IMG_HEIGHT] for x, y in coords]
    elif coord_type == "box":
        return [
            [x / IMG_WIDTH, y / IMG_HEIGHT, w / IMG_WIDTH, h / IMG_HEIGHT]
            for x, y, w, h in coords
        ]
    else:
        raise ValueError(f"Unknown coord_type: {coord_type}")

# %% [markdown]
# ### Loading an example video
#
# We assume that the video is stored as either **a list of JPEG frames with filenames like `<frame_index>.jpg`** or **an MP4 video**.
#
# Note that you can extract their JPEG frames using ffmpeg (https://ffmpeg.org/) as follows:
# ```
# ffmpeg -i <your_video>.mp4 -q:v 2 -start_number 0 <output_dir>/'%05d.jpg'
# ```
# where `-q:v` generates high-quality JPEG frames and `-start_number 0` asks ffmpeg to start the JPEG file from `00000.jpg`.

# %%
# "video_path" needs to be either a JPEG folder or a MP4 video file
video_path = f"{sam3_root}/cvu/data/S0_V1.mp4"
video_path = f"../cvu/data/S0_V1.mp4"

# %%
# load "video_frames_for_vis" for visualization purposes (they are not used by the model)
if isinstance(video_path, str) and video_path.endswith(".mp4"):
    cap = cv2.VideoCapture(video_path)
    video_frames_for_vis = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        video_frames_for_vis.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    cap.release()
else:
    video_frames_for_vis = glob.glob(os.path.join(video_path, "*.jpg"))
    try:
        # integer sort instead of string sort (so that e.g. "2.jpg" is before "11.jpg")
        video_frames_for_vis.sort(
            key=lambda p: int(os.path.splitext(os.path.basename(p))[0])
        )
    except ValueError:
        # fallback to lexicographic sort if the format is not "<frame_index>.jpg"
        print(
            f'frame names are not in "<frame_index>.jpg" format: {video_frames_for_vis[:5]=}, '
            f"falling back to lexicographic sort."
        )
        video_frames_for_vis.sort()

# %%
import cv2
import gc

def preprocess_video(input_path, output_path="temp_optimized.mp4", target_fps=10, target_width=1280):
    """
    Reduces FPS and resizes the video to save VRAM while preserving aspect ratio.
    """
    print(f"Optimizing video: {target_width}p width and {target_fps} FPS...")
    
    cap = cv2.VideoCapture(input_path)
    if not cap.isOpened():
        return input_path
        
    original_fps = cap.get(cv2.CAP_PROP_FPS)
    orig_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    orig_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    # Calculate new dimensions (preserving aspect ratio)
    ratio = target_width / float(orig_width)
    target_height = int(orig_height * ratio)
    
    frame_skip = max(1, round(original_fps / target_fps))
    
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, original_fps / frame_skip, (target_width, target_height))
    
    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        if frame_count % frame_skip == 0:
            # Resize frame
            resized_frame = cv2.resize(frame, (target_width, target_height))
            out.write(resized_frame)
        frame_count += 1
        
    cap.release()
    out.release()
    print("Optimization complete.")
    return output_path

# %%
gc.collect()
torch.cuda.empty_cache()

optimized_path = preprocess_video(video_path, target_fps=10, target_width=1280)
# Out:
# Optimizing video: 1280p width and 10 FPS...
# Optimization complete.

# %% [markdown]
# ### Opening an inference session on this video
#
# SAM 3 requires stateful inference for interactive video segmentation, so we need to initialize an **inference session** on this video.
#
# During initialization, it loads all the video frames and stores their pixels in the session state.

# %%
response = predictor.handle_request(
    request=dict(
        type="start_session",
        resource_path=optimized_path,
        offload_video_to_cpu=True,
        offload_state_to_cpu=True,
    )
)
session_id = response["session_id"]
# Out:
# frame loading (OpenCV) [rank=0]: 100%|██████████| 229/229 [00:01<00:00, 124.73it/s]
# INFO 2026-04-27 17:56:54,602 193877 sam3_base_predictor.py: 134: started new session a3c51143-28a8-4dd5-a60f-0cf8d9cb5845

# %% [markdown]
# ### Video promptable concept segmentation with text
#
# Using SAM 3 you can describe objects using natural language, and the model will automatically detect and track all instances of that object throughout the video.
#
# In the example below, we add a text prompt on frame 0 and propagation throughout the video. Here we use the text prompt "person" to detect all people in the video. SAM 3 will automatically identify multiple person instances and assign each a unique object ID.
#
# Note that the first call might be slower due to setting up buffers. **You can rerun all the cells below when measuring speed.**

# %%
# note: in case you already ran one text prompt and now want to switch to another text prompt
# it's required to reset the session first (otherwise the results would be wrong)
torch.cuda.empty_cache()
_ = predictor.handle_request(
    request=dict(
        type="reset_session",
        session_id=session_id,
    )
)

# %%
prompt_text_str = "glass bottle;"
frame_idx = 0  # add a text prompt on frame 0
torch.cuda.empty_cache()
response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        text=prompt_text_str,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[18], line 4
#       1 prompt_text_str = "glass bottle;"
#       2 frame_idx = 0  # add a text prompt on frame 0
#       3 torch.cuda.empty_cache()
# ----> 4 response = predictor.handle_request(
#       5     request=dict(
#       6         type="add_prompt",
#       7         session_id=session_id,
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/sam3_video_predictor.py:159, in Sam3VideoPredictorMultiGPU.handle_request(self, request)
#     156     for rank in range(1, self.world_size):
#     157         self.command_queues[rank].put((request, False))
# --> 159 response = super().handle_request(request)
#     161 if self.world_size > 1:
#     162     torch.distributed.barrier()  # wait for all ranks to finish
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/sam3_base_predictor.py:52, in Sam3BasePredictor.handle_request(self, request)
#      45     return self.start_session(
#      46         resource_path=request["resource_path"],
#      47         session_id=request.get("session_id", None),
#      48         offload_video_to_cpu=request.get("offload_video_to_cpu", False),
#      49         offload_state_to_cpu=request.get("offload_state_to_cpu", False),
#      50     )
#      51 elif request_type == "add_prompt":
# ---> 52     return self.add_prompt(
#      53         session_id=request["session_id"],
#      54         frame_idx=request["frame_index"],
#      55         text=request.get("text", None),
#      56         points=request.get("points", None),
#      57         point_labels=request.get("point_labels", None),
#      58         clear_old_points=request.get("clear_old_points", True),
#      59         bounding_boxes=request.get("bounding_boxes", None),
#      60         bounding_box_labels=request.get("bounding_box_labels", None),
#      61         clear_old_boxes=request.get("clear_old_boxes", True),
#      62         output_prob_thresh=request.get(
#      63             "output_prob_thresh",
#      64             getattr(self, "default_output_prob_thresh", 0.5),
#      65         ),
#      66         obj_id=request.get("obj_id", None),
#      67         rel_coordinates=request.get("rel_coordinates", True),
#      68     )
#      69 elif request_type == "remove_object":
#      70     return self.remove_object(
#      71         session_id=request["session_id"],
#      72         frame_idx=request.get("frame_index", 0),
#      73         obj_id=request["obj_id"],
#      74     )
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/sam3_base_predictor.py:194, in Sam3BasePredictor.add_prompt(self, session_id, frame_idx, text, points, point_labels, clear_old_points, bounding_boxes, bounding_box_labels, clear_old_boxes, output_prob_thresh, obj_id, rel_coordinates)
#     191 filtered_kwargs = {k: v for k, v in kwargs.items() if k in valid_params}
#     193 with torch.autocast(device_type="cuda", dtype=torch.bfloat16):
# --> 194     frame_idx, outputs = self.model.add_prompt(**filtered_kwargs)
#     195 return {"frame_index": frame_idx, "outputs": outputs}
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/sam3_video_inference.py:1391, in Sam3VideoInferenceWithInstanceInteractivity.add_prompt(self, inference_state, frame_idx, text_str, boxes_xywh, box_labels, points, point_labels, obj_id, rel_coordinates)
#    1380     return self.add_tracker_new_points(
#    1381         inference_state,
#    1382         frame_idx,
#    (...)   1387         use_prev_mem_frame=self.use_prev_mem_frame,
#    1388     )
#    1389 else:
#    1390     # SAM3 prompts
# -> 1391     return super().add_prompt(
#    1392         inference_state,
#    1393         frame_idx,
#    1394         text_str=text_str,
#    1395         boxes_xywh=boxes_xywh,
#    1396         box_labels=box_labels,
#    1397     )
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/sam3_video_inference.py:903, in Sam3VideoInference.add_prompt(self, inference_state, frame_idx, text_str, boxes_xywh, box_labels)
#     897     boxes_cxcywh, box_labels, geometric_prompt = self._get_visual_prompt(
#     898         inference_state, frame_idx, boxes_cxcywh, box_labels
#     899     )
#     901     inference_state["per_frame_geometric_prompt"][frame_idx] = geometric_prompt
# --> 903 out = self._run_single_frame_inference(
#     904     inference_state, frame_idx, reverse=False
#     905 )
#     906 return frame_idx, self._postprocess_output(inference_state, out)
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/sam3_video_inference.py:380, in Sam3VideoInference._run_single_frame_inference(self, inference_state, frame_idx, reverse)
#     369 has_geometric_prompt = (
#     370     inference_state["per_frame_geometric_prompt"][frame_idx] is not None
#     371 )
#     372 # run inference for the current frame
#     373 (
#     374     obj_id_to_mask,
#     375     obj_id_to_score,
#     376     tracker_states_local_new,
#     377     tracker_metadata_new,
#     378     frame_stats,
#     379     _,
# --> 380 ) = self._det_track_one_frame(
#     381     frame_idx=frame_idx,
#     382     num_frames=inference_state["num_frames"],
#     383     reverse=reverse,
#     384     input_batch=input_batch,
#     385     geometric_prompt=(
#     386         inference_state["constants"]["empty_geometric_prompt"]
#     387         if not has_geometric_prompt
#     388         else inference_state["per_frame_geometric_prompt"][frame_idx]
#     389     ),
#     390     tracker_states_local=tracker_states_local,
#     391     tracker_metadata_prev=inference_state["tracker_metadata"],
#     392     feature_cache=inference_state["feature_cache"],
#     393     orig_vid_height=inference_state["orig_height"],
#     394     orig_vid_width=inference_state["orig_width"],
#     395     is_image_only=inference_state["is_image_only"],
#     396     allow_new_detections=has_text_prompt or has_geometric_prompt,
#     397 )
#     398 # update inference state
#     399 inference_state["tracker_inference_states"] = tracker_states_local_new
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/sam3_video_base.py:407, in Sam3VideoBase._det_track_one_frame(self, frame_idx, num_frames, reverse, input_batch, geometric_prompt, tracker_states_local, tracker_metadata_prev, feature_cache, orig_vid_height, orig_vid_width, is_image_only, allow_new_detections)
#     390 """
#     391 This function handles one-step inference for the DenseTracking model in an SPMD manner.
#     392 At a high-level, all GPUs execute the same function calls as if it's done on a single GPU,
#    (...)    399   it contains both global and local masklet information
#     400 """
#     402 # Step 1: run backbone and detector in a distributed manner -- this is done via Sam3ImageOnVideoMultiGPU,
#     403 # a MultiGPU model (assigned to `self.detector`) that shards frames in a round-robin manner.
#     404 # It returns a "det_out" dict for `frame_idx` and fills SAM2 backbone features for `frame_idx`
#     405 # into `feature_cache`. Despite its distributed inference under the hood, the results would be
#     406 # the same as if it is running backbone and detector for every frame on a single GPU.
# --> 407 det_out = self.run_backbone_and_detection(
#     408     frame_idx=frame_idx,
#     409     num_frames=num_frames,
#     410     reverse=reverse,
#     411     input_batch=input_batch,
#     412     geometric_prompt=geometric_prompt,
#     413     feature_cache=feature_cache,
#     414     allow_new_detections=allow_new_detections,
#     415 )
#     417 # Step 2: each GPU propagates its local SAM2 states to get the SAM2 prediction masks.
#     418 # the returned `tracker_low_res_masks_global` contains the concatenated masklet predictions
#     419 # gathered from all GPUs (as if they are propagated on a single GPU). Note that this step only
#     420 # runs the SAM2 propagation step, but doesn't encode new memory for the predicted masks;
#     421 # we defer memory encoding to `run_tracker_update_execution_phase` after resolving all heuristics.
#     422 if tracker_metadata_prev == {}:
#     423     # initialize masklet metadata if it's uninitialized (empty dict)
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/sam3_video_base.py:568, in Sam3VideoBase.run_backbone_and_detection(self, frame_idx, num_frames, input_batch, geometric_prompt, feature_cache, reverse, allow_new_detections)
#     565 max_frame_num_to_track = tracking_bounds.get("max_frame_num_to_track")
#     566 start_frame_idx = tracking_bounds.get("propagate_in_video_start_frame_idx")
# --> 568 sam3_image_out, _ = self.detector.forward_video_grounding_multigpu(
#     569     backbone_out={
#     570         "img_batch_all_stages": input_batch.img_batch,
#     571         **text_outputs,
#     572     },
#     573     find_inputs=input_batch.find_inputs,
#     574     geometric_prompt=geometric_prompt,
#     575     frame_idx=frame_idx,
#     576     num_frames=num_frames,
#     577     multigpu_buffer=feature_cache["multigpu_buffer"],
#     578     track_in_reverse=reverse,
#     579     # also get the SAM2 backbone features
#     580     return_tracker_backbone_feats=True,
#     581     # run NMS as a part of distributed computation
#     582     run_nms=self.det_nms_thresh > 0.0,
#     583     nms_prob_thresh=self.score_threshold_detection,
#     584     nms_iou_thresh=self.det_nms_thresh,
#     585     # pass max_frame_num_to_track to respect tracking limits
#     586     max_frame_num_to_track=max_frame_num_to_track,
#     587     propagate_in_video_start_frame_idx=start_frame_idx,
#     588 )
#     589 # note: detections in `sam3_image_out` has already gone through NMS
#     590 pred_probs = sam3_image_out["pred_logits"].squeeze(-1).sigmoid()
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/sam3_image.py:755, in Sam3ImageOnVideoMultiGPU.forward_video_grounding_multigpu(self, backbone_out, find_inputs, geometric_prompt, frame_idx, num_frames, multigpu_buffer, track_in_reverse, return_sam2_backbone_feats, run_nms, nms_prob_thresh, nms_iou_thresh, **kwargs)
#     753 if frame_idx not in multigpu_buffer:
#     754     with torch.profiler.record_function("build_multigpu_buffer_next_chunk1"):
# --> 755         self._build_multigpu_buffer_next_chunk(
#     756             backbone_out=backbone_out,
#     757             find_inputs=find_inputs,
#     758             geometric_prompt=geometric_prompt,
#     759             frame_idx_begin=frame_idx_curr_b,
#     760             frame_idx_end=frame_idx_curr_e,
#     761             num_frames=num_frames,
#     762             multigpu_buffer=multigpu_buffer,
#     763             run_nms=run_nms,
#     764             nms_prob_thresh=nms_prob_thresh,
#     765             nms_iou_thresh=nms_iou_thresh,
#     766         )
#     768 # read out the current frame's results from `multigpu_buffer`
#     769 out = {}
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/sam3_image.py:835, in Sam3ImageOnVideoMultiGPU._build_multigpu_buffer_next_chunk(self, backbone_out, find_inputs, geometric_prompt, frame_idx_begin, frame_idx_end, num_frames, multigpu_buffer, run_nms, nms_prob_thresh, nms_iou_thresh)
#     833 # `forward_grounding` (from base class `Sam3ImageOnVideo`) runs the detector on a single frame
#     834 with torch.profiler.record_function("forward_grounding"):
# --> 835     out_local = self.forward_grounding(
#     836         backbone_out=backbone_out,
#     837         find_input=find_inputs[frame_idx_local_gpu],
#     838         find_target=None,
#     839         geometric_prompt=geometric_prompt,
#     840     )
#     841 if run_nms:
#     842     with torch.profiler.record_function("nms_masks"):
#     843         # run NMS as a post-processing step on top of the detection outputs
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/sam3_image.py:449, in Sam3Image.forward_grounding(self, backbone_out, find_input, find_target, geometric_prompt, **kwargs)
#     440 def forward_grounding(
#     441     self,
#     442     backbone_out,
#    (...)    446     **kwargs,
#     447 ):
#     448     with torch.profiler.record_function("SAM3Image._encode_prompt"):
# --> 449         prompt, prompt_mask, backbone_out = self._encode_prompt(
#     450             backbone_out, find_input, geometric_prompt
#     451         )
#     452     # Run the encoder
#     453     with torch.profiler.record_function("SAM3Image._run_encoder"):
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/sam3_image.py:183, in Sam3Image._encode_prompt(self, backbone_out, find_input, geometric_prompt, visual_prompt_embed, visual_prompt_mask, encode_text, prev_mask_pred)
#     180 txt_feats = backbone_out["language_features"][:, txt_ids]
#     181 txt_masks = backbone_out["language_mask"][txt_ids]
# --> 183 feat_tuple = self._get_img_feats(backbone_out, find_input.img_ids)
#     184 backbone_out, img_feats, img_pos_embeds, vis_feat_sizes = feat_tuple
#     186 if prev_mask_pred is not None:
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/sam3_image.py:161, in Sam3Image._get_img_feats(self, backbone_out, img_ids)
#     155 id_mapping = torch.full(
#     156     (len(img_batch),), -1, dtype=torch.long, device=self.device
#     157 )
#     158 id_mapping[unique_ids] = torch.arange(len(unique_ids), device=self.device)
#     159 backbone_out = {
#     160     **backbone_out,
# --> 161     **self.backbone.forward_image(image),
#     162     "id_mapping": id_mapping,
#     163 }
#     164 assert "backbone_fpn" in backbone_out
#     165 return self._get_img_feats(backbone_out, img_ids=img_ids)
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/vl_combiner.py:81, in SAM3VLBackbone.forward_image(self, samples)
#      80 def forward_image(self, samples: torch.Tensor):
# ---> 81     return activation_ckpt_wrapper(self._forward_image_no_act_ckpt)(
#      82         samples=samples,
#      83         act_ckpt_enable=self.act_ckpt_whole_vision_backbone and self.training,
#      84     )
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/act_ckpt_utils.py:88, in activation_ckpt_wrapper.<locals>.act_ckpt_wrapper(act_ckpt_enable, use_reentrant, *args, **kwargs)
#      84     ret = checkpoint.checkpoint(
#      85         module, *args, use_reentrant=use_reentrant, **kwargs
#      86     )
#      87 else:
# ---> 88     ret = module(*args, **kwargs)
#      90 return ret
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/vl_combiner.py:88, in SAM3VLBackbone._forward_image_no_act_ckpt(self, samples)
#      86 def _forward_image_no_act_ckpt(self, samples):
#      87     # Forward through backbone
# ---> 88     sam3_features, sam3_pos, sam2_features, sam2_pos = self.vision_backbone.forward(
#      89         samples
#      90     )
#      91     if self.scalp > 0:
#      92         # Discard the lowest resolution features
#      93         sam3_features, sam3_pos = (
#      94             sam3_features[: -self.scalp],
#      95             sam3_pos[: -self.scalp],
#      96         )
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/necks.py:110, in Sam3DualViTDetNeck.forward(self, tensor_list)
#     102 def forward(
#     103     self, tensor_list: List[torch.Tensor]
#     104 ) -> Tuple[
#    (...)    108     Optional[List[torch.Tensor]],
#     109 ]:
# --> 110     xs = self.trunk(tensor_list)
#     111     sam3_out, sam3_pos = [], []
#     112     sam2_out, sam2_pos = None, None
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/vitdet.py:985, in ViT.forward(self, tensor_list)
#     983     x = checkpoint.checkpoint(blk, x, use_reentrant=False)
#     984 else:
# --> 985     x = blk(x)
#     986 if (i == self.full_attn_ids[-1]) or (
#     987     self.return_interm_layers and i in self.full_attn_ids
#     988 ):
#     989     if i == self.full_attn_ids[-1]:
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/vitdet.py:732, in Block.forward(self, x)
#     729     H, W = x.shape[1], x.shape[2]
#     730     x, pad_hw = window_partition(x, self.window_size)
# --> 732 x = self.ls1(self.attn(x))
#     733 # Reverse window partition
#     734 if self.window_size > 0:
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/cvu-sam3/lib/python3.12/site-packages/sam3/model/vitdet.py:617, in Attention.forward(self, x)
#     613         x = flash_attn_func(
#     614             q.transpose(1, 2), k.transpose(1, 2), v.transpose(1, 2)
#     615         ).transpose(1, 2)
#     616     else:
# --> 617         x = F.scaled_dot_product_attention(q, k, v)
#     618 else:
#     619     raise NotImplementedError
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1.60 GiB. GPU 0 has a total capacity of 10.90 GiB of which 15.12 MiB is free. Including non-PyTorch memory, this process has 10.88 GiB memory in use. Of the allocated memory 10.58 GiB is allocated by PyTorch, and 154.39 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ###  Removing objects
#
# We can remove individual objects using their id.
#
# As an example, let's remove object 2 (which is the dancer in the front).

# %%
# we pick id 2, which is the dancer in the front
obj_id = 2
torch.cuda.empty_cache()
response = predictor.handle_request(
    request=dict(
        type="remove_object",
        session_id=session_id,
        obj_id=obj_id,
    )
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Adding new objects with point prompts
#
# We can add new objects through point prompts.
#
# Assuming that we've changed our mind, and now that we want to add back the dancer in the front (whom we just removed in the step above). We can use interactive clicks to add her back.

# %%
sample_img = Image.fromarray(load_frame(video_frames_for_vis[0]))

IMG_WIDTH, IMG_HEIGHT = sample_img.size

# %%
# let's add back the dancer via point prompts.
# we will use a single positive click to add the dancer back.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Refining an existing object with point prompts
#
# We can also refine the segmentation mask of an existing object through point prompts.
#
# Assuming that we've changed our mind (again) -- for Object ID 2 (the dancer in the front whom we just added back in the step above), now we only want to segment her T-shirt instead of her whole body. We can adjust the segmentation mask with a few more positive and negative clicks.

# %%
# For the dancer in the front, suppose now we only want to segment her T-shirt instead of her whole body
# we will use 2 positive clicks and 2 negative clicks to select her shirt.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [740, 450],  # positive click
        [760, 630],  # negative click
        [840, 640],  # negative click
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1, 0, 0, 1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Close session
#
# Each session is tied to a single video. We can close the session after inference to free up its resources.
#
# (Then, you may start a new session on another video.)

# %%
# finally, close the inference session to free its GPU resources
# (you may start a new session on another video)
_ = predictor.handle_request(
    request=dict(
        type="close_session",
        session_id=session_id,
    )
)

# %% [markdown]
# ### Clean-up
#
# After all inference is done, we can shutdown the predictor to free up the multi-GPU process group.

# %%
# after all inference is done, we can shutdown the predictor
# to free up the multi-GPU process group
predictor.shutdown()
